# %%
from sklearn.datasets import make_regression
import numpy as np 
import pandas as pd

# %%
X,y = make_regression(n_samples=4,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
# lets apply ols

from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X,y)
reg.score(X,y)
# Out:
# 0.44362163090968376

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
# its a b value now we manuly ranodom b value to achive this value by gradiant disant (khod ke throw self )
reg.intercept_
# Out:
# np.float64(26.15963284313262)

# %%
# is line ke jisi banani he line choseing random value of b when we dont know b value
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red')

# %%
# lets apply gradiant discent assuming slope is constant m = 78.35
# and lets assume the starting value for intercept b = 0
# y = mx + b formula to find best value of b
y_pred = ((78.35 * X) + 0).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='ols')
plt.plot(X , y_pred,color='green' ,label='b=0')
plt.legend()
plt.show()

# %%
m = 78.35
b = 0

# %%
# again check los and try to fit green line on read line

loss_slop = -2 * np.sum(y- m*X.ravel()-b)
loss_slop
# Out:
# np.float64(-209.27763408209216)

# %%
# lets take learning rate  = 0.1
lr = 0.1
step_size = loss_slop*lr
step_size
# Out:
# np.float64(-20.927763408209216)

# %%
# calculate the new intercept
b = b- step_size

# %%
y_pred = ((78.35 * X) + b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='ols')
plt.plot(X , y_pred,color='green' ,label='b=0')
plt.legend()
plt.show()

# %%
# interaction 2 

loss_slop = -2 * np.sum(y- m*X.ravel()-b)
loss_slop
# Out:
# np.float64(-41.85552681641843)

# %%
step_size = loss_slop*lr
step_size
# Out:
# np.float64(-4.185552681641844)

# %%
b = b - step_size
b
# Out:
# np.float64(25.11331608985106)

# %%
y_pred2 = ((m*X) + b )

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='ols')
plt.plot(X , y_pred2,color='green' ,label='b=0')
plt.legend()
plt.show()

# %%
# take this step in loop  

b = 100 
m = 78.35

learning_rate = 0.1    # learning rate is used to varation ko kam karta he slop ka jese jese hum pass ate he target slop ke pass change value bhi kam hota he 
 
spoches = 10 

for i in range(spoches):

    loss_slop = -2 * np.sum(y - m * X.ravel() - b)
    
    step_size =  learning_rate * loss_slop 

    b = b - step_size
    y_pred = m * X + b  

    plt.plot(X,y_pred)

    plt.scatter(X,y)

# %% [markdown]
# # we are creating two classes for calculating b and slop m
# lets start

# %%
from sklearn.datasets import make_regression
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
X , y = make_regression(n_samples=100, n_features=1, n_informative=1 , noise=20, n_targets=1)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

reg.fit(X,y)
# Out:
# LinearRegression()

# %%
m = reg.coef_

# %%
reg.intercept_
# Out:
# np.float64(0.1000563544005055)

# %%
class GDregressor :

    def __init__(self,learning_rate, epoches):
        self.m = m
        self.b = -120
        self.learning_rate = learning_rate
        self.epochs = epoches


    def fit(X, y):
       # calculate the b using GD
      for i in range(self.epochs):
         loss_slop = -2 * np.sum(y - m*X.ravel() - self.b)  
         b = b - (self.lr * loss_slop)

# %%
class GDregressor :

    def __init__(self,learning_rate, epoches):
        self.m = m
        self.b = -120
        self.learning_rate = learning_rate
        self.epochs = epoches


    def fit(self,X, y):
       # calculate the b using GD
      for i in range(self.epochs):
         loss_slop = -2 * np.sum(y - m*X.ravel() - self.b)  
         b = self.b - (self.learning_rate * loss_slop)

# %%
Gd = GDregressor(0.1,10)

# %%
Gd.fit(X,y)
# Out:
# None

# %% [markdown]
# # multiple linear regression from skreatch lets build now lets start by using mathmatical formul that we
# learn and solve on notebook so get ready

# %%
from sklearn.datasets import load_diabetes
import numpy as np 
from sklearn.linear_model import LinearRegression

# %%
X,y = load_diabetes(return_X_y=True)

print(X,y)
# Out:
# [[ 0.03807591  0.05068012  0.06169621 ... -0.00259226  0.01990749
#   -0.01764613]
#  [-0.00188202 -0.04464164 -0.05147406 ... -0.03949338 -0.06833155
#   -0.09220405]
#  [ 0.08529891  0.05068012  0.04445121 ... -0.00259226  0.00286131
#   -0.02593034]
#  ...
#  [ 0.04170844  0.05068012 -0.01590626 ... -0.01107952 -0.04688253
#    0.01549073]
#  [-0.04547248 -0.04464164  0.03906215 ...  0.02655962  0.04452873
#   -0.02593034]
#  [-0.04547248 -0.04464164 -0.0730303  ... -0.03949338 -0.00422151
#    0.00306441]] [151.  75. 141. 206. 135.  97. 138.  63. 110. 310. 101.  69. 179. 185.
#  118. 171. 166. 144.  97. 168.  68.  49.  68. 245. 184. 202. 137.  85.
#  131. 283. 129.  59. 341.  87.  65. 102. 265. 276. 252.  90. 100.  55.
#   61.  92. 259.  53. 190. 142.  75. 142. 155. 225.  59. 104. 182. 128.
#   52.  37. 170. 170.  61. 144.  52. 128.  71. 163. 150.  97. 160. 178.
#   48. 270. 202. 111.  85.  42. 170. 200. 252. 113. 143.  51.  52. 210.
# ...

# %%
# now split train and test data using linear model selection
from sklearn.model_selection import train_test_split
x_train ,x_test, y_train , y_test = train_test_split(X,y ,test_size=0.2, random_state=2 )

# %%
# Out:
# array([ 48., 276.,  47., 175.,  60.,  81., 242., 197., 137., 129., 138.,
#        160., 116., 101., 147., 100., 144.,  69., 219., 107., 168., 236.,
#        109., 321., 128.,  43.,  72.,  55., 141., 283.,  59., 150., 346.,
#        124., 186., 308., 272., 190.,  63.,  91.,  72.,  65., 158.,  90.,
#        185.,  45., 199., 206.,  61., 139., 296., 281., 122.,  95.,  40.,
#        127., 145., 108., 185.,  53., 132., 101., 263.,  94., 295., 259.,
#        232., 124.,  77., 102.,  96.,  83., 263.,  71., 246.,  66., 115.,
#        222.,  93., 129., 128., 163.,  99.,  92., 179., 140.,  94.,  97.,
#        174.,  61., 202., 135.,  88., 152.,  69.,  31., 248., 275.,  64.,
#         94.,  99., 109.,  90.,  37., 164., 274., 200.,  49., 214.,  85.,
#        154., 134., 164., 189.,  64., 150., 245.,  67., 265., 151.,  75.,
#        208., 292.,  90.,  59.,  44., 277.,  67.,  72., 182., 135., 275.,
#         95., 332., 214.,  53., 141., 102.,  88.,  74., 103., 292.,  70.,
# ...

# %% [markdown]
# x_train.shape

# %%
x_train.shape
# Out:
# (353, 10)

# %%
y_test.shape
# Out:
# (89,)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.439933866156897

# %%
# m ki difrent weight value
model.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
model.intercept_
# Out:
# np.float64(151.88331005254167)
